# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Automobile.csv')
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
 df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
cylinders_mpg = df.groupby('cylinders')['mpg'].mean()
cylinders_mpg
# Out:
# cylinders
# 3    20.550000
# 4    29.286765
# 5    27.366667
# 6    19.985714
# 8    14.963107
# Name: mpg, dtype: float64

# %%
origin_mpg = df.groupby('origin')['mpg'].mean()
origin_mpg
# Out:
# origin
# europe    27.891429
# japan     30.450633
# usa       20.083534
# Name: mpg, dtype: float64

# %%
mpg_trend_year = df.groupby('model_year')['mpg'].mean()
mpg_trend_year
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x=missing_values.index, y=missing_values.values)
plt.title("Missing Values per Column")
plt.ylabel("Number of Missing Values")
plt.xticks(rotation=45)
plt.show()

# %%
origin_mpg = df.groupby('origin')['mpg'].mean()
plt.figure(figsize=(8, 5))
origin_mpg.plot(kind='bar', color='salmon')
plt.title("Average MPG by Origin")
plt.xlabel("Origin")
plt.ylabel("Average MPG")
plt.show()

# %%
mpg_trend_year = df.groupby('model_year')['mpg'].mean()
plt.figure(figsize=(10, 5))
mpg_trend_year.plot(marker='o', color='teal')
plt.title("MPG Trend Over Model Years")
plt.xlabel("Model Year")
plt.ylabel("Average MPG")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 8))
correlations = df.corr(numeric_only=True)
sns.heatmap(correlations, annot=True, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %% [markdown]
# Overall Conclusion
# The automobile data analysis reveals significant insights into factors influencing fuel efficiency in cars manufactured between 1970 and 1982. Key takeaways include the positive impact of smaller engines and reduced weight on mpg, the global shift toward more fuel-efficient vehicles over time, and regional differences in vehicle design philosophy. This analysis can inform automotive industry stakeholders, environmental policymakers, and consumers who are interested in fuel efficiency and eco-friendly vehicles
